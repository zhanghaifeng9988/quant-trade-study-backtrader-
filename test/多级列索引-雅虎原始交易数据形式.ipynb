# %%
# import pandas as pd
import yfinance as yf

tickers = ['AAPL', 'SPY', 'TSLA']
data1 = yf.download(tickers, start='2023-12-01', end='2024-01-01',progress=False, multi_level_index=False) 
# false是为了屏蔽掉下载的进度条，再1个false 是为了禁用多级列表，多只股票是没办法禁用多级列表的。
returns1 = data.pct_change().dropna()
print('数据下载完成')
print(f'\n 原始数据是:\n {data.tail(20)}') # 这是多级索引数据
print(f'\n 收益率数据是：\n {returns1.tail(20)}')


ticker = ['AAPL']
data2 = yf.download(ticker, start='2023-12-01', end='2024-01-01',progress=False, multi_level_index=False) 
returns2 = data.pct_change().dropna()
print('数据下载完成')
print(f'\n 原始数据是:\n {data2.tail(20)}') # 这是多级索引数据
print(f'\n 收益率数据是：\n {returns2.tail(20)}')
# Out:
# 数据下载完成
#
#  原始数据是:
#  Price            Close                                High              \
# Ticker            AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2023-12-01  189.099503  444.999939  238.830002  189.415913  445.533035
# 2023-12-04  187.309753  442.663910  235.580002  187.922824  445.019271
# 2023-12-05  191.255081  442.576691  238.720001  192.224108  443.536276
# 2023-12-06  190.167419  440.793213  239.369995  192.580096  444.747893
# 2023-12-07  192.095596  444.156647  242.639999  192.817421  444.806053
# 2023-12-08  193.519485  446.066132  243.839996  193.796350  446.599228
# 2023-12-11  191.017792  447.801117  239.740005  191.324335  447.975611
# 2023-12-12  192.530670  449.846344  237.009995  192.540553  449.943279
# 2023-12-13  195.744293  456.049774  239.289993  195.783839  456.301798
# 2023-12-14  195.892609  457.513367  251.050003  197.385702  459.180542
# 2023-12-15  195.358658  456.760132  253.500000  196.179355  458.093465
# ...
